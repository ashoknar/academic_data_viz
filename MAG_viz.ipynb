# %% [markdown]
# <a href="https://colab.research.google.com/github/ashoknar/academic_data_viz/blob/master/MAG_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ashoknar/academic_data_viz
# Out:
# Cloning into 'academic_data_viz'...
# remote: Enumerating objects: 104, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 104 (delta 47), reused 76 (delta 27), pack-reused 0
# Receiving objects: 100% (104/104), 28.15 MiB | 19.29 MiB/s, done.
# Resolving deltas: 100% (47/47), done.

# %%
cd academic_data_viz/
# Out:
# /content/academic_data_viz

# %%
# !python main.py
# Out:
# <Figure size 640x480 with 9 Axes>
# <Figure size 640x480 with 9 Axes>

# %%
from fos_calc import process_data

# Topic names can be chosen from topics at Microsoft Academic
# https://academic.microsoft.com/topics

topic1 = "quantum physics"
topic2 = "computer science"

start_year = 2010
end_year = 2021

process_data(topic_1=topic1, topic_2=topic2, start_y=start_year, end_y=end_year)
